# %% [markdown]
# <a href="https://colab.research.google.com/github/DMTX2410/TL-P1/blob/main/SA_PU1_Modelo_para_predicci%C3%B3n_de_lluvia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Práctica #1: Modelo para predicción de lluvia**
#
# *Centro Universitario de Ciencias Exactas e Ingenierías*
#
# *División de Tecnologías para la Integración Ciber-Humana*
#
# *Ingeniería Biomédica*
#
# <br>
#
# *Mtra. Sofía Alejandra Aguilar Valdez*
#
# 2 de septiembre de 2022

# %% [markdown]
# ## **Información del equipo**
#
# **```NOMBRES:```**
#
# *   Espino Rojas Francisco Julian
# *   Manrique Torres Jafet Daniel
# *   Sanchez Rodríguez Christopher William
#
#
# **```CÓDIGOS:```**
#
# *   221349453
# *   217467298
# *   215658088
#
#
# ```LINK REPOSITORIO:```
#
# https://github.com/DMTX2410/TL-P1.git

# %% [markdown]
# ## **Contenido**
#
#
#
# 1.   Resumen
# 2.   Marco teórico
# 3.   Objetivos
# 4.   Materiales y métodos
# 5.   Resultados
# 6.   Discusión
# 7.   Conclusiones
# 8.   Referencias

# %% [markdown]
# # **1. Resumen**
#
# La implementación de una red neuronal multicapa supervisada para predecir un conjunto de datos meteorológicos que permite adquirir los conocimientos sobre funcionamiento y comportamiento en base a los datos de entrenamiento y validación, para ello se utiliza biblioteca comoKeras y bibliotecas relacionadas que permiten desarrollar este tipo de redes complejas de manera sencilla gracias a sus funciones y clases. Para poder manipular los datos se transforman a tensores, para posterior definir los datos de entrenamiento y validación, parte clave es convertir estos datos en data loaders, en donde se definen los tamaños de los batch a usar. El tipo de predicciones depende de la elección de la función de activación. Por lo que para este tipo de caso se opta por usar la función ReLu en las capas, para este modelo se utiliza un total de 64 entradas con una dimensión de 3 en la capa de entrada y 1 una capa de salida. Con todo lo anterior definido se entrena a la red con una función de costo CrossEntropy permitiendo ajustar los pesos mediante backpropagation y un algoritmo de optimización Adam. Para el entrenamiento definen los hiperparametros como las épocas a usar que en este caso es de 10. Mediante el análisis de los resultados obtenidos del entrenamiento y evaluación se determina si el modelo tiende al underfitting o overfitting.

# %% [markdown]
# # **2. Marco teórico**
#
# **Red Neuronal Multicapa (Perceptrón Multicapa):**
#
# Históricamente estas redes eran primeramente perceptrones, pero ahora, estas redes están constituidas por redes sigmoides o por otro tipo de neuronas con otro tipo de función de activación (por ejemplo, ReLu).
#
# Estas redes están conformadas por una capa de neuronas de entrada que representan los valores de entrada; en seguida, una o varias capas ocultas que están conectadas todas con cada una de las neuronas de la capa anterior; y por último, una capa de salida de una o varias neuronas que predicen el resultado.
#
#
# **Modelo de activación (ReLu)**
#
# El modelo de activación es uan parte fundamental de las redes neuronales ya que le permiten aprender de manera más eficiente.
#
# La función ReLu tiene una función de activación como la siguiente:
# ![ReLU.png](data:image/png;base64,...)
#
# Ofreciendo como ventajas:
#
# *   Mejor propagación de gradiente.
# *   Más rápida de calcular que sigmoide.
# *   Cálculo eficiente: comparación, suma y multiplicación.
# *   Comportamiento lineal.
#
# **Overfitting**
#
# Es un fenómeno en el que un algoritmo predictivo presenta baja tasa de acierto en sus resultados. Existen 3 posibles causas:
#
# 1.   Los datos no representan acertadamente la realidad de lo que deberá predecir.
# 2.   Variables irrelevantes.
# 3.   Se han sobrepasado el número de épocas.
#
# **Underfitting**
#
# Se da cuando el modelo de aprendizaje presenta resultados deficientes, ya sea porque el modelo es muy simple o insufiente para capturar particularidades de los datos. Se presenta alta parciabilidad (bias).
#
# **Librerías**
#
# ---
#
# **Pandas:** Librería basada en la librería NumPy y su función es el manejo de datos y análisis de estructuras de datos. Permite acceder a los datos mediante nombres o índices y escribir y leer ficheros de tipo Excel, así como realizar operaciones eficientes entre datos. Dispone de tres estructuras de datos diferentes:
#
# * Series. Estructura de una dimensión.
# * DataFrame: Estructura de dos dimensiones (tablas).
# * Panel: Estructura de tres dimensiones (cubos).
#
# ---
#
# **Numpy:**  Permite el cálculo numérico y el análisis de datos, especialmente para un gran volumen de datos.
# Dentro de ella existen los arrays multidimensionales de un mismo tipo de dato.
#
# ---
#
# **Matplotlib:** Permite la generación de gráficos a partir de datos.
#
#
# ---
#
# **Keras:** Consiste en una biblioteca de redes neuronales artificiales de código abierto, emplea redes convolucionales y recurrentes, lo quye la vuelven ideal para entrenar modelos de deep learning.
#
# ---
#
#
# **Función de costo**
# Es aquella que se encarga de comparar el error arrojado por una red neuronal y el valor esperado con la finalidad de obtimizar los parámetros que hay implícitos dentro de esta.
#
# **Cross Entropy Loss:**
#
# Se trata de una función que solo penaliza a las predicciones que fueron correctas. La ecuación que emplea es la siguiente:
#
# ![ecuac111.png](data:image/png;base64,...)
#
# Donde cada letra representa...
#
# i: la clase.
#
# c: el número de clases.
#
# y_i: la clase real.
#
# ŷ_i: la clase predicha.
#
#
# **Epoch**
#
# Puede definirse como un ciclo completo a través de todo el conjunto de datos de entrenamiento e indica la cantidad de pasadas que el algoritmo de aprendizaje automático ha completado durante ese entrenamiento.
#
# **Procesamiento por lotes (Batch processing)**
#
# Procesamiento que se realiza sin la necesidad de alguna interacción del usaurio (no supervisado). Este tipo de procesamiento es ideal cuando se manejan procesos repetitivos sobre una gran cantidad de datos, además de que reducen la probabilidad de error a casi cero.
#
# **Tensores**
#
# Estructuras de datos que almacenan y manipulan datos de un único tipo de datos. Permiten representar vectores y matrices de cualquier dimensión. Pueden utilizarse con la ayuda de la librería torch.Tensor.

# %% [markdown]
# # **3. Objetivos**
# **Objetivo general:**
#
# Generar un modelo de predicción para determinar la probabilidad de que llueva bajo determinadas condiciones climáticas.
#
# **Objetivos específicos:**
#
# * Utilizar un modelo de Deep learning para predecir en base al set de datos establecido.
# * Comparar trabajos anteriores con el modelo actual.
# * Establecer el uso y estudio de distintas librerias en python para nuestro modelo de aprendizaje.
# * Medir el coste del model.
# * Diseñar el modelo evitando overfiting y underfiting.

# %% [markdown]
# # **4. Materiales y métodos**
#
# ## *Materiales*
#
# Describir este conjunto de datos [[1]](https://www.kaggle.com/code/fatmakursun/rain-forecasting-with-artificial-neural-network/data).
#
# Los datos fueron recopilados del Aeropuerto Internacional de Seattle-Tacoma. El conjunto de datos contiene cinco columnas:
#
# FECHA = la fecha de la observación.
#
# PRCP = la cantidad de precipitación, en pulgada.
#
# TMAX = la temperatura máxima para ese día, en grados Fahrenheit.
#
# TMIN = la temperatura mínima para ese día, en grados Fahrenheit.
#
# LLUVIA = VERDADERO si se observó lluvia ese día, FALSO si no fuera así.
#
#
# ## *Métodos*
#
# 1. Esquema de metodología
# 2. Descripción de los métodos y su implementación en código en forma de narrativa.

# %%
#Importamos las librerias
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import metrics
import matplotlib.pyplot as plt
import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dropout

# %%
#Se carga el archivo que contiene los datos
filepath = "https://raw.githubusercontent.com/DMTX2410/TL-P1/main/seattleWeather_1948-2017.csv" #Se guarda la ruta en la variable filepath
df = pd.read_csv(filepath) #Se asignan los datos de la ruta a la variable df

# %%
#Se convierte la columna de lluvia a valores enteros y se guardan en una nueva columna "rain"
df['rain']=[1 if i==True else 0 for i in df['RAIN']] #Definimos como 1 si el valor es verdadero y como 0 si el valor es falso.

# %%
#Se eliminan los valores nulos
df.dropna(inplace=True) # El metodo dropna permite filtrar los valores de una estructura de datos pandas para dejar solo aquellos no nulos.

# %%
#Definimos X y Y
x = df[['PRCP', 'TMAX', 'TMIN']] #Aqui definimos que solo estas 3 columnas se guardaran en x
y = df['rain'] #rain al ser el valor con el cual se valida, se guarda en Y

# %%
#Se definen las variables de entrenamiento
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=42)#Se deja un tamaño de entrenamiento del 80%

# %%
#Usamos el modelo secuencial de Keras
def build_model(): #Se define como función
  model = keras.Sequential()
  #Se usa una función de activacion de tipo relu, debido a la eficacia de esta en este tipo de casos
  model.add(keras.layers.Dense(64, activation='relu', input_dim=x.shape[1]))#La capa de entrada tendra un total de 64 neuronas
  model.add(keras.layers.Dense(32, activation='relu'))#La capa oculta tendra un total de 32 neuronas
  model.add(keras.layers.Dense(1, activation='sigmoid'))#La capa de salida tendra solo una, la función de activación sera de tipo sigmoide debido al tipo de capa.
  model.compile(optimizer= "adam", loss='binary_crossentropy', metrics=['accuracy'])
  #Se especifica la forma como se calcularán los parámetros de la línea recta (w y b). 
  #Para ello se utiliza adam como modelo de optimizacion y crossentropy para determinar los pesos mediante backpropagation
  return model

# %%
#Detalles del modelo
model = build_model()#Instanciamos el modelo
model.summary()#Nos permite ver los parametros del modelo
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                256
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# ...
# Total params: 2,369
# Trainable params: 2,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Entrenamos la red neuronal
history = model.fit(x_train, y_train, batch_size=10, epochs=10,validation_split =0.2,verbose=2)
#Le asignamos un batch de 10 y epocas de 10, esto con el fin de obtener una precision alta a menor cantidad de epocas.
#Para la validacion utilizaremos el 20% de las pruebas.
# Out:
# Epoch 1/10
# 1635/1635 - 3s - loss: 0.4958 - accuracy: 0.7560 - val_loss: 0.3710 - val_accuracy: 0.8346 - 3s/epoch - 2ms/step
# Epoch 2/10
# 1635/1635 - 3s - loss: 0.3447 - accuracy: 0.8426 - val_loss: 0.2972 - val_accuracy: 0.8655 - 3s/epoch - 2ms/step
# Epoch 3/10
# 1635/1635 - 3s - loss: 0.2723 - accuracy: 0.8828 - val_loss: 0.2120 - val_accuracy: 0.9185 - 3s/epoch - 2ms/step
# Epoch 4/10
# 1635/1635 - 3s - loss: 0.2104 - accuracy: 0.9180 - val_loss: 0.2040 - val_accuracy: 0.9178 - 3s/epoch - 2ms/step
# Epoch 5/10
# 1635/1635 - 3s - loss: 0.1756 - accuracy: 0.9365 - val_loss: 0.1212 - val_accuracy: 0.9550 - 3s/epoch - 2ms/step
# Epoch 6/10
# 1635/1635 - 7s - loss: 0.1396 - accuracy: 0.9525 - val_loss: 0.1061 - val_accuracy: 0.9873 - 7s/epoch - 4ms/step
# Epoch 7/10
# 1635/1635 - 6s - loss: 0.1119 - accuracy: 0.9634 - val_loss: 0.0856 - val_accuracy: 0.9958 - 6s/epoch - 4ms/step
# Epoch 8/10
# ...

# %%
#Grafica de perdidas vs iteraciones
hist = pd.DataFrame(history.history)#Extraemos los datos del entrenamiento y validación
hist['epoch'] = history.epoch #Asignamos el valor de las epocas
plt.figure() #Creamos la figura
plt.xlabel('Epoch')#Se asigna el nombre del ehe x
plt.ylabel('Loss')#Se asigna el nombre del ehe y
plt.title('Perdidas vs Iteraciones')#Se asigna el nombre del titulo de la grafica
plt.plot(hist['epoch'], hist['loss'], label = 'Train Error')#Graficamos los valores de entrenamiento
plt.plot(hist['epoch'], hist['val_loss'], label = 'Test Error')#Graficamos los valores de validacion
plt.ylim(0,0.5)#Definimos los limites de y
plt.legend()#Ploteamos los nombres de las graficas

# %%
#Precision de la neurona
prediction_nn = model.predict(x_test) #Usamos la funcion de predict sobre la variable de test
prediction_nn = [1 if y>=0.5 else 0 for y in prediction_nn]#Definimos los parametros
print(classification_report(y_test, prediction_nn))#Imprimos los datos
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2953
#            1       1.00      0.88      0.94      2157
#
#     accuracy                           0.95      5110
#    macro avg       0.96      0.94      0.95      5110
# weighted avg       0.95      0.95      0.95      5110

# %% [markdown]
# # **5. Resultados**
#
# En base a las medidas que el los valores de precisión y recall en relación con el valor F1 obtenido se puede aseverar que los resultados de predicción en el modelo implementado son óptimos en cuestión de medidas dado que con el máximo suport de aproximadamente 5110 valores se consiguió un valor del 95 en F1 con lo que podemos validar que el modelo cumple con lo buscado tal como se muestra en la siguiente figura.
#
# ![WhatsApp Image 2022-09-08 at 5.26.27 PM.jpeg](data:image/jpeg;base64,...)
#
#
# En suma, a que en el total de las épocas buscadas nuestro acurrency fue de aproximadamente el 97 porciento con lo que es posible objetar que podemos predecir la probabilidad de lluvia dados los tres parámetros utilizados. En cuestión de la función de costo, esta fue optimizada conforme las épocas realizadas avanzaban, por que el valor de predicción fue alzándose progresivamente tal y como lo muestra la gráfica de perdida e iteraciones:
#
#
# ![WhatsApp Image 2022-09-08 at 5.26.06 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **6. Discusión**
#
# El modelo no tiende al overfitting  dado que el valor de F1 score tiene un alto índice de efectividad, siendo este parámetro una relación armónica entre el Recall (instancias relevantes) y el precision (nuestro valor predictivo positivo).

# %% [markdown]
# # **7. Conclusiones**
#
# Como conclusión grupal se obtuvo un desarrollo al aprendizaje de redes neuronales multicapa, partiendo desde la obtención del conjunto de datos a analizar, pues existen grandes cantidades de foros dedicados a ellos y que pueden ser de gran utilidad al momento de crear y entrenar una red. Sin embargo, hubo un gran tropiezo al momento de emplear los datos en pytorch puesto que no logramos resolver un error causado por el tamaño de matrices y alargando el proceso, todo este error nos llevo a optar por keras. Tras una larga documentación logramos entender como programar una red neuronal con un modelo secuencial. Así mismo identificamos y aprendimos a controlar los hiperparametros para conseguir un resultado ideal, cosa que nos llevo a estudiar y lograr identificar que ocasiona el overfitiing y underfitting y los diferentes métodos para evitarlos.
# Hablando de la experiencia de trabajar en equipo, resulto algo compleja al momento de plantear el problema y dividir las tareas, puesto que las capacidades y entendimiento de cada uno son diferentes, aunado a ello el hecho de tener que usar una plataforma como github para control.

# %% [markdown]
# # **8. Referencias**
#
# [1] Pb, V. (2020, February 18). Perceptron. Kaggle. Retrieved June 1, 2022, from https://www.kaggle.com/code/prashfio/perceptron/notebook
#
# [2] Conoce qué son las funciones de activación y cómo puedes crear tu función de activación usando Python, R y Tensorflow. (2021, 30 agosto). Jahaziel Ponce. Recuperado 8 de septiembre de 2022, de https://jahazielponce.com/funciones-de-activacion-y-como-puedes-crear-la-tuya-usando-python-r-y-tensorflow/#ReLU
#
# [3] Alberca, A. S. (2022b, junio 14). La librería Pandas. Aprende con Alf. Recuperado 8 de septiembre de 2022, de https://aprendeconalf.es/docencia/python/manual/pandas/
#
# [4] JVS-Informática. (2020, 17 noviembre). Procesamiento por lotes o Batch. JVS Informática Blog. Recuperado 8 de septiembre de 2022, de https://www.jvs-informatica.com/blog/glosario/procesamiento-por-lotes-batch/
#
# [5] Morales, J. (2020, 2 julio). ¿Qué es Underfitting y Cómo lo Detectamos? DataSmarts Español. Recuperado 8 de septiembre de 2022, de https://datasmarts.net/es/que-es-underfitting-y-como-lo-detectamos/
#
# [6] El Perceptrón Multicapa | Interactive Chaos. (s. f.). Recuperado 8 de septiembre de 2022, de https://interactivechaos.com/es/manual/tutorial-de-deep-learning/el-perceptron-multicapa
#
# [7] Between, S. I. T. (s. f.-b). ¿Qué es el overfitting en machine learning? | BETWEEN Technology. Recuperado 8 de septiembre de 2022, de https://impulsate.between.tech/overfitting-machine-learning
#
# [8] Alberca, A. S. (2022a, mayo 12). La librería Numpy. Aprende con Alf. Recuperado 8 de septiembre de 2022, de https://aprendeconalf.es/docencia/python/manual/numpy/
#
# [9] R, P., & Ra, P. (2021b, julio 5). Qué es Keras - PiperLab, Big data & Data science. PiperLab. Recuperado 8 de septiembre de 2022, de https://piperlab.es/glosario-de-big-data/keras/
#
# [10] Keras: biblioteca de cÃ3digo abierto para crear redes neuronales. (2020, 8 octubre). IONOS Digital Guide. Recuperado 8 de septiembre de 2022, de https://www.ionos.mx/digitalguide/online-marketing/marketing-para-motores-de-busqueda/que-es-keras/
